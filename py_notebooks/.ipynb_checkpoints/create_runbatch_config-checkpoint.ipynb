# %%
# script: create_runbatch_config
# authors: Olga Botvinnik & Lincoln Harris
# date: 10.11.18
#
# Trying to build the input file to give tracer_pipeline.rf (required for batch mode run)

# %%
# try to get all of the run prefixes w/in nonImmune_bams_9.27
bucketPrefixes = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/'
f = 'nonImmune_bams_9.27_prefixes.txt'
! aws s3 ls $bucketPrefixes > $f
! cat $f
# Out:
#                            PRE 170125/
#                            PRE 170129/
#                            PRE 170202/
#                            PRE 170215/
#                            PRE 170504/
#                            PRE 170508/
#                            PRE 170510/
#                            PRE 171120/
#                            PRE 180226/
#                            PRE 180307/
#                            PRE 180319/
#                            PRE 180320/
#                            PRE 180405/
#                            PRE 180423/
#                            PRE 180516/
#                            PRE 180519/
#                            PRE 180601/
#                            PRE 180604/
#                            PRE 180711/
#                            PRE 180831/
#                            PRE 180911/
# 2018-09-27 12:03:37          0

# %%
# read run names into a dataframe
#     with pandas!!
import pandas as pd
pd.options.display.max_colwidth = 500 # module config? 

runs_df = pd.read_table(f, delim_whitespace=True, header=None, names=['is_prefix', 'run_name'])
runs_df
# Out:
#      is_prefix  run_name
# 0          PRE   170125/
# 1          PRE   170129/
# 2          PRE   170202/
# 3          PRE   170215/
# 4          PRE   170504/
# 5          PRE   170508/
# 6          PRE   170510/
# 7          PRE   171120/
# 8          PRE   180226/
# 9          PRE   180307/
# 10         PRE   180319/
# 11         PRE   180320/
# 12         PRE   180405/
# 13         PRE   180423/
# 14         PRE   180516/
# 15         PRE   180519/
# 16         PRE   180601/
# 17         PRE   180604/
# 18         PRE   180711/
# 19         PRE   180831/
# 20         PRE   180911/
# 21  2018-09-27  12:03:37

# %%
# can i add a full_path col? 
runs_df['full_path'] = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/' + runs_df['run_name']
runs_df
# Out:
#      is_prefix  run_name  \
# 0          PRE   170125/
# 1          PRE   170129/
# 2          PRE   170202/
# 3          PRE   170215/
# 4          PRE   170504/
# 5          PRE   170508/
# 6          PRE   170510/
# 7          PRE   171120/
# 8          PRE   180226/
# 9          PRE   180307/
# 10         PRE   180319/
# 11         PRE   180320/
# 12         PRE   180405/
# 13         PRE   180423/
# 14         PRE   180516/
# 15         PRE   180519/
# 16         PRE   180601/
# 17         PRE   180604/
# 18         PRE   180711/
# 19         PRE   180831/
# 20         PRE   180911/
# 21  2018-09-27  12:03:37
#
#                                                              full_path
# 0    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170125/
# 1    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170129/
# 2    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170202/
# 3    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170215/
# 4    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170504/
# 5    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170508/
# 6    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/170510/
# 7    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/171120/
# 8    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/
# 9    s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180307/
# 10   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180319/
# 11   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180320/
# 12   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180405/
# 13   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180423/
# 14   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180516/
# 15   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180519/
# 16   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180601/
# 17   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180604/
# 18   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180711/
# 19   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180831/
# 20   s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180911/
# 21  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/12:03:37

# %%
# get all of the cells in a given run directory
prefix = 's3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/'
txt = 'runX_cells.txt'
! aws s3 ls $prefix > $txt
! cat $txt
# Out:
#                            PRE A1_B001800/
#                            PRE A21_1001000366/
#                            PRE A21_B003049/
#                            PRE A2_B001797/
#                            PRE A2_B001798/
#                            PRE A2_B001799/
#                            PRE A2_B003785/
#                            PRE A3_B001798/
#                            PRE A4_1001000362/
#                            PRE A4_B001798/
#                            PRE A4_B003785/
#                            PRE A5_1001000365/
#                            PRE A5_B001798/
#                            PRE A5_B001799/
#                            PRE A5_B001800/
#                            PRE A6_1001000377/
#                            PRE B21_B003049/
#                            PRE B2_B001797/
#                            PRE B2_B001798/
#                            PRE B2_B001799/
#                            PRE B3_B001797/
#                            PRE B3_B001798/
#                            PRE B3_B001799/
#                            PRE B3_B003785/
#                            PRE B4_B001797/
#                            PRE B5_1001000362/
#                            PRE B5_B001797/
#                            PRE B5_B001799/
#                            PRE B5_B003785/
#                            PRE B6_1001000377/
#                            PRE C16_1001000377/
#                            PRE C1_B001798/
#                            PRE C2_B001798/
#                            PRE C2_B001799/
#                            PRE C3_1001000362/
#                            PRE C3_B001799/
#                            PRE C3_B003785/
#                            PRE C4_B001798/
#                            PRE C5_B001797/
#                            PRE C5_B001798/
#                            PRE C5_B001799/
#                            PRE C5_B001800/
#                            PRE D15_1001000365/
#                            PRE D19_1001000365/
#                            PRE D1_B001797/
#                            PRE D1_B001798/
#                            PRE D2_B001799/
#                            PRE D3_B001799/
#                            PRE D4_B001797/
#                            PRE E1_1001000366/
#                            PRE E1_B001797/
#                            PRE E1_B001798/
#                            PRE E1_B001800/
#                            PRE E3_B001798/
#                            PRE E3_B001799/
#                            PRE E3_B001800/
#                            PRE E4_1001000366/
#                            PRE E4_B003785/
#                            PRE E5_B001797/
#                            PRE E5_B001799/
#                            PRE F1_B001797/
#                            PRE F1_B001799/
#                            PRE F1_B001800/
#                            PRE F2_B001798/
#                            PRE F3_B001798/
#                            PRE F4_1001000362/
#                            PRE F5_B001799/
#                            PRE F5_B001800/
#                            PRE G17_1001000365/
#                            PRE G1_1001000413/
#                            PRE G1_B001797/
#                            PRE G1_B001799/
#                            PRE G1_B001800/
#                            PRE G1_B003785/
#                            PRE G2_1001000365/
#                            PRE G2_B003785/
#                            PRE G3_B001797/
#                            PRE G3_B001799/
#                            PRE G3_B003785/
#                            PRE G4_B001797/
#                            PRE G4_B001799/
#                            PRE G5_B001797/
#                            PRE G5_B001798/
#                            PRE G5_B001799/
#                            PRE G5_B003785/
#                            PRE H12_1001000365/
#                            PRE H19_1001000363/
#                            PRE H1_B001797/
#                            PRE H1_B001799/
#                            PRE H1_B003785/
#                            PRE H21_B003049/
#                            PRE H2_B001798/
#                            PRE H2_B001799/
#                            PRE H3_1001000413/
#                            PRE H3_B003785/
#                            PRE H4_B001800/
#                            PRE I18_1001000365/
#                            PRE I1_B001797/
#                            PRE I1_B001798/
#                            PRE I2_B001797/
#                            PRE I2_B001799/
#                            PRE I2_B003785/
#                            PRE I3_B001797/
#                            PRE I3_B001799/
#                            PRE I4_B001797/
#                            PRE I4_B001800/
#                            PRE I5_B001797/
#                            PRE I5_B001799/
#                            PRE I5_B003785/
#                            PRE J11_1001000365/
#                            PRE J19_1001000377/
#                            PRE J1_B001797/
#                            PRE J1_B001798/
#                            PRE J2_B001797/
#                            PRE J2_B001800/
#                            PRE J2_B003785/
#                            PRE J3_B001797/
#                            PRE J3_B001798/
#                            PRE J3_B001799/
#                            PRE J3_B001800/
#                            PRE J4_B001799/
#                            PRE J5_B001797/
#                            PRE J5_B001798/
#                            PRE K16_1001000377/
#                            PRE K1_1001000362/
#                            PRE K1_B001797/
#                            PRE K1_B001799/
#                            PRE K1_B001800/
#                            PRE K2_B001797/
#                            PRE K2_B001798/
#                            PRE K2_B001800/
#                            PRE K3_B001797/
#                            PRE K3_B001798/
#                            PRE K3_B001799/
#                            PRE K4_B001797/
#                            PRE K4_B001800/
#                            PRE K5_B001797/
#                            PRE K5_B001798/
#                            PRE K5_B001799/
#                            PRE K5_B001800/
#                            PRE L1_B001797/
#                            PRE L1_B001798/
#                            PRE L1_B001799/
#                            PRE L1_B003785/
#                            PRE L2_1001000413/
#                            PRE L2_B001797/
#                            PRE L2_B001798/
#                            PRE L2_B001800/
#                            PRE L2_B003785/
#                            PRE L3_B001797/
#                            PRE L3_B001798/
#                            PRE L3_B001800/
#                            PRE L3_B003785/
#                            PRE L4_B001797/
#                            PRE L4_B001798/
#                            PRE L4_B001799/
#                            PRE L5_B001797/
#                            PRE L5_B001798/
#                            PRE M1_B001797/
#                            PRE M1_B001800/
#                            PRE M21_B003049/
#                            PRE M2_B001797/
#                            PRE M2_B001800/
#                            PRE M3_B001797/
#                            PRE M3_B001800/
#                            PRE M3_B003785/
#                            PRE M4_B001797/
#                            PRE M4_B001798/
#                            PRE M4_B001800/
#                            PRE M4_B003785/
#                            PRE M5_B001797/
#                            PRE N1_B001797/
#                            PRE N1_B001800/
#                            PRE N1_B003785/
#                            PRE N2_B001797/
#                            PRE N2_B001800/
#                            PRE N2_B003785/
#                            PRE N3_B001797/
#                            PRE N3_B001798/
#                            PRE N3_B001799/
#                            PRE N4_B001797/
#                            PRE N4_B001798/
#                            PRE N4_B001799/
#                            PRE N4_B001800/
#                            PRE N4_B003785/
#                            PRE N5_B001797/
#                            PRE N5_B003785/
#                            PRE O1_B001797/
#                            PRE O1_B001798/
#                            PRE O1_B001799/
#                            PRE O1_B001800/
#                            PRE O1_B003785/
#                            PRE O2_1001000413/
#                            PRE O2_B001797/
#                            PRE O2_B001798/
#                            PRE O2_B001799/
#                            PRE O2_B001800/
#                            PRE O2_B003785/
#                            PRE O3_B001797/
#                            PRE O3_B001800/
#                            PRE O4_B001797/
#                            PRE O4_B001800/
#                            PRE O4_B003785/
#                            PRE O5_B001797/
#                            PRE O5_B001798/
#                            PRE O5_B001799/
#                            PRE O5_B001800/
#                            PRE O5_B003785/
#                            PRE P1_1001000413/
#                            PRE P1_B001797/
#                            PRE P1_B001798/
#                            PRE P1_B001799/
#                            PRE P1_B001800/
#                            PRE P21_1001000366/
#                            PRE P2_B001797/
#                            PRE P2_B001798/
#                            PRE P2_B003785/
#                            PRE P3_B001797/
#                            PRE P3_B001800/
#                            PRE P3_B003785/
#                            PRE P4_B001797/
#                            PRE P4_B001800/
#                            PRE P4_B003785/
#                            PRE P5_B001797/
#                            PRE P5_B001798/
#                            PRE P5_B001799/
#                            PRE P5_B001800/
#                            PRE P5_B003785/

# %%
# read 180226 cell names into a dataframe
cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])
cells_df
# Out:
#     is_prefix        cell_name
# 0         PRE      A1_B001800/
# 1         PRE  A21_1001000366/
# 2         PRE     A21_B003049/
# 3         PRE      A2_B001797/
# 4         PRE      A2_B001798/
# 5         PRE      A2_B001799/
# 6         PRE      A2_B003785/
# 7         PRE      A3_B001798/
# 8         PRE   A4_1001000362/
# 9         PRE      A4_B001798/
# 10        PRE      A4_B003785/
# 11        PRE   A5_1001000365/
# 12        PRE      A5_B001798/
# 13        PRE      A5_B001799/
# 14        PRE      A5_B001800/
# 15        PRE   A6_1001000377/
# 16        PRE     B21_B003049/
# 17        PRE      B2_B001797/
# 18        PRE      B2_B001798/
# 19        PRE      B2_B001799/
# 20        PRE      B3_B001797/
# 21        PRE      B3_B001798/
# 22        PRE      B3_B001799/
# 23        PRE      B3_B003785/
# 24        PRE      B4_B001797/
# 25        PRE   B5_1001000362/
# 26        PRE      B5_B001797/
# 27        PRE      B5_B001799/
# 28        PRE      B5_B003785/
# 29        PRE   B6_1001000377/
# ..        ...              ...
# 198       PRE      O3_B001797/
# 199       PRE      O3_B001800/
# 200       PRE      O4_B001797/
# 201       PRE      O4_B001800/
# 202       PRE      O4_B003785/
# 203       PRE      O5_B001797/
# 204       PRE      O5_B001798/
# 205       PRE      O5_B001799/
# 206       PRE      O5_B001800/
# 207       PRE      O5_B003785/
# 208       PRE   P1_1001000413/
# 209       PRE      P1_B001797/
# 210       PRE      P1_B001798/
# 211       PRE      P1_B001799/
# 212       PRE      P1_B001800/
# 213       PRE  P21_1001000366/
# 214       PRE      P2_B001797/
# 215       PRE      P2_B001798/
# 216       PRE      P2_B003785/
# 217       PRE      P3_B001797/
# 218       PRE      P3_B001800/
# 219       PRE      P3_B003785/
# 220       PRE      P4_B001797/
# 221       PRE      P4_B001800/
# 222       PRE      P4_B003785/
# 223       PRE      P5_B001797/
# 224       PRE      P5_B001798/
# 225       PRE      P5_B001799/
# 226       PRE      P5_B001800/
# 227       PRE      P5_B003785/
#
# [228 rows x 2 columns]

# %%
# ls one of our s3 cell directories
test_files = ! aws s3 ls $prefix\P5_B001799/ # what does backslash do? 
test_files
# Out:
# []

# %%
# get full s3 paths for fastq file (R1), then add them to a new col in cells_df

def get_fastqs_R1(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    fq_line = [x for x in lines if x.endswith('R1_001.fastq.gz')][0] # get the fastq files, specifically
    fq_basename = fq_line.split()[-1]
    return f'{s3_location}{fq_basename}'


cells_df['input_fq_1'] = cells_df['cell_name'].map(get_fastqs_R1) # applying function, and assigning output to new col in cells_df
cells_df.head()
# Out:
#   is_prefix        cell_name  \
# 0       PRE      A1_B001800/
# 1       PRE  A21_1001000366/
# 2       PRE     A21_B003049/
# 3       PRE      A2_B001797/
# 4       PRE      A2_B001798/
#
#                                                                                                              input_fq  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                            input_fq_1
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz

# %%
# get full s3 paths for fastq file (R2), then add them to a new col in cells_df

def get_fastqs_R2(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    try:
        fq_line = [x for x in lines if x.endswith('R2_001.fastq.gz')][0] # get the fastq files, specifically
        fq_basename = fq_line.split()[-1]
        #print(s3_location)
        return f'{s3_location}{fq_basename}'
    except IndexError:
        return

cells_df['input_fq_2'] = cells_df['cell_name'].map(get_fastqs_R2) # applying function, and assigning output to new col in cells_df
cells_df.head()
# Out:
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A3_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_1001000362/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A4_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A5_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A6_1001000377/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B21_B003049/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B2_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B3_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B4_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_1001000362/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B5_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/B6_1001000377/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C16_1001000377/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C1_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C2_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C2_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C3_1001000362/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C3_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C4_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C5_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C5_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/C5_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D15_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D19_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D1_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D2_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/D4_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E1_1001000366/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E1_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E1_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E3_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E3_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E4_1001000366/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E4_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E5_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/E5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F1_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F1_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F2_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F3_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F4_1001000362/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/F5_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G17_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G1_1001000413/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G1_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G1_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G1_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G2_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G2_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G3_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G3_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G4_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G4_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G5_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G5_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/G5_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H12_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H19_1001000363/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H1_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H1_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H21_B003049/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H2_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H2_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H3_1001000413/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H3_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/H4_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I18_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I1_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I2_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I2_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I2_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I3_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I4_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I4_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I5_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I5_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/I5_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J11_1001000365/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J19_1001000377/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J1_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J1_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J2_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J2_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J2_B003785/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J3_B001797/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J3_B001798/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J3_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J3_B001800/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J4_B001799/
# s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/J5_B001797/
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-92ea2f700cf5> in <module>()
#      10
#      11
# ---> 12 cells_df['input_fq_2'] = cells_df['cell_name'].map(get_fastqs_R2) # applying function, and assigning output to new col in cells_df
#      13 cells_df.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-18-92ea2f700cf5> in get_fastqs_R2(cell)
#       4     s3_location = f'{prefix}{cell}' #f?
#       5     lines = get_ipython().getoutput('aws s3 ls $s3_location')
# ----> 6     fq_line = [x for x in lines if x.endswith('R2_001.fastq.gz')][0] # get the fastq files, specifically
#       7     fq_basename = fq_line.split()[-1]
#       8     print(s3_location)
#
# IndexError: list index out of range

# %%
# add a sample_id col
cells_df['sample_id'] = cells_df.cell_name.str.strip('/') # getting rid of the forward slashes
cells_df.head()
# Out:
#   is_prefix        cell_name  \
# 0       PRE      A1_B001800/
# 1       PRE  A21_1001000366/
# 2       PRE     A21_B003049/
# 3       PRE      A2_B001797/
# 4       PRE      A2_B001798/
#
#                                                                                                              input_fq  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#                                                                                                            input_fq_1  \
# 0         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A1_B001800/A1_B001800_S277_R1_001.fastq.gz
# 1  s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_1001000366/A21_1001000366_S57_R1_001.fastq.gz
# 2        s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A21_B003049/A21_B003049_S81_R1_001.fastq.gz
# 3          s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001797/A2_B001797_S26_R1_001.fastq.gz
# 4         s3://darmanis-group/singlecell_lungadeno/immuneCells_9.27/180226/A2_B001798/A2_B001798_S110_R1_001.fastq.gz
#
#         sample_id
# 0      A1_B001800
# 1  A21_1001000366
# 2     A21_B003049
# 3      A2_B001797
# 4      A2_B001798

# %%
# building the output vcf string
import os

cells_df['output_prefix'] = cells_df['input_fq_1'].map(os.path.dirname)
cells_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2e634306c25a> in <module>()
#       2 import os
#       3
# ----> 4 cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
#       5 cells_df.head()
#
# NameError: name 'cells_df' is not defined

# %%
# building the output vcf string
cells_df['output_vcf'] = cells_df.apply( # not sure how this works
    lambda x: '{output_prefix}/{sample_id}.vcf'.format(**x), axis=1)
cells_df.head()
# Out:
#   is_prefix       cell_name  \
# 0       PRE  C3_1001000403/
# 1       PRE  E3_1001000362/
# 2       PRE  F1_1001000362/
# 3       PRE  G5_1001000362/
# 4       PRE  H1_1001000362/
#
#                                                                                                                           input_bam  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
#
#        sample_id             id  \
# 0  C3_1001000403  C3_1001000403
# 1  E3_1001000362  E3_1001000362
# 2  F1_1001000362  F1_1001000362
# 3  G5_1001000362  G5_1001000362
# 4  H1_1001000362  H1_1001000362
#
#                                                                        output_prefix  \
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403
# 1  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362
#
#                                                                                             output_vcf
# 0  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403.vcf
# 1  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362.vcf
# 2  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362.vcf
# 3  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362.vcf
# 4  s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362.vcf

# %%
# subset cells_df by only what we want
cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']

samples_df = cells_df[cols_to_keep]
samples_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-29974e103a69> in <module>()
#       2 cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']
#       3
# ----> 4 samples_df = cells_df[cols_to_keep]
#       5 samples_df
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['sample_id' 'output_vcf'] not in index"

# %%
# writeFunc()
#     write this guy to a file
#def writeFunc():
import json

out_dir = '../gatk/big_test'

# write samples_df to file
! mkdir -p $out_dir
big_df.to_csv(f'{out_dir}/samples_big.csv', index=False)

# write a config file
config =     {
    "program": "../../reflow/gatk_pipeline.rf",
    "runs_file": "samples_big.csv"
}

with open(f'{out_dir}/config.json', 'w') as f:
    json.dump(config, f)
    
! head -n 3 $out_dir/samples_big.csv $out_dir/config.json
# Out:
# ==> ../gatk/big_test/samples_big.csv <==
# input_bam,sample_id,output_vcf
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170125/G12_1001000292/G12_1001000292_S72.homo.Aligned.out.sorted.bam,G12_1001000292,s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170125/G12_1001000292/G12_1001000292.vcf
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170125/H2_1001000293/H2_1001000293_S144.homo.Aligned.out.sorted.bam,H2_1001000293,s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170125/H2_1001000293/H2_1001000293.vcf
#
# ==> ../gatk/big_test/config.json <==
# {"program": "../../reflow/gatk_pipeline.rf", "runs_file": "samples_big.csv"}

# %%
## can we make a function or a class to do everything we just did? 

# get_bam()
#     gets full paths to bam files
def get_bam(cell):
    s3_location = f'{prefix}{cell}' #f? 
    lines = ! aws s3 ls $s3_location
    bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
    bam_basename = bam_line.split()[-1]
    return f'{s3_location}{bam_basename}'

# driver()
#     Gets cell names given a prefix, and sets up dataframe
def driver(prefix): 
    #print("in driver")
    txt = 'runX_cells.txt'
    ! aws s3 ls $prefix > $txt
    
    # read into a pandas dataframe
    cells_df = pd.read_table(txt, delim_whitespace=True, header=None, names=['is_prefix', 'cell_name'])

    # call get_bam() and add 'input_bam' col
    cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) # how does this map thing work? 
    
    # get rid of forward slashes and add 'sample_id' col
    cells_df['sample_id'] = cells_df.cell_name.str.strip('/')
    
    # add output_prefix col
    cells_df['output_prefix'] = cells_df['input_bam'].map(os.path.dirname)
    
    # building the output vcf string
    cells_df['output_vcf'] = cells_df.apply( # not sure how this works
    lambda x: '{output_prefix}/{sample_id}.vcf'.format(**x), axis=1)
    
    # subset cells_df by only what we want
    cols_to_keep = ['input_bam', 'sample_id', 'output_vcf']
    samples_df = cells_df[cols_to_keep]
    
    return(samples_df)

# %%
# call this our Main() i guess
#       run driver function

big_df = pd.DataFrame() # init empty dataframe

for i in range(0, len(runs_df.index)-1):
    global prefix # dont like this
    prefix = runs_df['full_path'][i]
    print(prefix)
    curr_df = driver(prefix)
    toConcat = [big_df, curr_df]
    big_df = pd.concat(toConcat)
    
big_df.head()
# Out:
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170125/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170202/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170215/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170504/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170508/
# s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/170510/
# ^C
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-33ebf02aae1d> in <module>()
#       8     prefix = runs_df['full_path'][i]
#       9     print(prefix)
# ---> 10     curr_df = driver(prefix)
#      11     toConcat = [big_df, curr_df]
#      12     big_df = pd.concat(toConcat)
#
# <ipython-input-6-ce162f6a263d> in driver(prefix)
#      21
#      22     # call get_bam() and add 'input_bam' col
# ---> 23     cells_df['input_bam'] = cells_df['cell_name'].map(get_bam) # how does this map thing work?
#      24
#      25     # get rid of forward slashes and add 'sample_id' col
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-6-ce162f6a263d> in get_bam(cell)
#       6     s3_location = f'{prefix}{cell}' #f?
#       7     lines = get_ipython().getoutput('aws s3 ls $s3_location')
# ----> 8     bam_line = [x for x in lines if x.endswith('bam')][0] # get the bam file, specifically
#       9     bam_basename = bam_line.split()[-1]
#      10     return f'{s3_location}{bam_basename}'
#
# IndexError: list index out of range

# %%
big_df
# Out:
#                                                                                                                               input_bam  \
# 0      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403_S123.homo.Aligned.out.sorted.bam
# 1       s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362_S99.homo.Aligned.out.sorted.bam
# 2      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362_S121.homo.Aligned.out.sorted.bam
# 3      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362_S149.homo.Aligned.out.sorted.bam
# 4      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362_S169.homo.Aligned.out.sorted.bam
# 5      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H7_1001000377/H7_1001000377_S295.homo.Aligned.out.sorted.bam
# 6    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/J11_1001000367/J11_1001000367_S179.homo.Aligned.out.sorted.bam
# 7      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/L2_1001000362/L2_1001000362_S266.homo.Aligned.out.sorted.bam
# 8    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M10_1001000365/M10_1001000365_S166.homo.Aligned.out.sorted.bam
# 9      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M2_1001000413/M2_1001000413_S230.homo.Aligned.out.sorted.bam
# 10     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M3_1001000362/M3_1001000362_S291.homo.Aligned.out.sorted.bam
# 11     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/N2_1001000380/N2_1001000380_S218.homo.Aligned.out.sorted.bam
# 12   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O23_1001000377/O23_1001000377_S179.homo.Aligned.out.sorted.bam
# 13   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O24_1001000377/O24_1001000377_S180.homo.Aligned.out.sorted.bam
# 14            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O7_B001797/O7_B001797_S67.homo.Aligned.out.sorted.bam
# 0          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A10_B000863/A10_B000863_S250.homo.Aligned.out.sorted.bam
# 1           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B000861/A11_B000861_S83.homo.Aligned.out.sorted.bam
# 2           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B003067/A11_B003067_S95.homo.Aligned.out.sorted.bam
# 3           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A14_B003067/A14_B003067_S98.homo.Aligned.out.sorted.bam
# 4          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A16_B003654/A16_B003654_S112.homo.Aligned.out.sorted.bam
# 5          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A17_B003654/A17_B003654_S113.homo.Aligned.out.sorted.bam
# 6          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A18_B003654/A18_B003654_S114.homo.Aligned.out.sorted.bam
# 7          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A19_B003654/A19_B003654_S115.homo.Aligned.out.sorted.bam
# 8            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B000863/A1_B000863_S241.homo.Aligned.out.sorted.bam
# 9             s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B002568/A1_B002568_S13.homo.Aligned.out.sorted.bam
# 10            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003067/A1_B003067_S85.homo.Aligned.out.sorted.bam
# 11           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003646/A1_B003646_S109.homo.Aligned.out.sorted.bam
# 12           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003648/A1_B003648_S145.homo.Aligned.out.sorted.bam
# 13         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A21_B003654/A21_B003654_S117.homo.Aligned.out.sorted.bam
# 14         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A22_B003067/A22_B003067_S106.homo.Aligned.out.sorted.bam
# ..                                                                                                                                  ...
# 928      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P2_B002572/P2_B002572_S74_L004.homo.Aligned.out.sorted.bam
# 929     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B001464/P3_B001464_S267_L001.homo.Aligned.out.sorted.bam
# 930      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B001475/P3_B001475_S87_L003.homo.Aligned.out.sorted.bam
# 931     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B001543/P3_B001543_S123_L003.homo.Aligned.out.sorted.bam
# 932     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B002571/P3_B002571_S135_L002.homo.Aligned.out.sorted.bam
# 933     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P4_B001464/P4_B001464_S268_L001.homo.Aligned.out.sorted.bam
# 934     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P4_B002571/P4_B002571_S136_L002.homo.Aligned.out.sorted.bam
# 935     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001464/P5_B001464_S269_L001.homo.Aligned.out.sorted.bam
# 936      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001475/P5_B001475_S89_L003.homo.Aligned.out.sorted.bam
# 937     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001543/P5_B001543_S125_L003.homo.Aligned.out.sorted.bam
# 938     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001545/P5_B001545_S209_L003.homo.Aligned.out.sorted.bam
# 939      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001556/P5_B001556_S41_L003.homo.Aligned.out.sorted.bam
# 940     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B002571/P5_B002571_S137_L002.homo.Aligned.out.sorted.bam
# 941      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B002572/P5_B002572_S77_L004.homo.Aligned.out.sorted.bam
# 942     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001464/P6_B001464_S270_L001.homo.Aligned.out.sorted.bam
# 943     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001543/P6_B001543_S126_L003.homo.Aligned.out.sorted.bam
# 944     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001545/P6_B001545_S210_L003.homo.Aligned.out.sorted.bam
# 945      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001556/P6_B001556_S42_L003.homo.Aligned.out.sorted.bam
# 946      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B001475/P7_B001475_S91_L003.homo.Aligned.out.sorted.bam
# 947     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B001543/P7_B001543_S127_L003.homo.Aligned.out.sorted.bam
# 948     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B002571/P7_B002571_S139_L002.homo.Aligned.out.sorted.bam
# 949      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B002572/P7_B002572_S79_L004.homo.Aligned.out.sorted.bam
# 950     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B001543/P8_B001543_S128_L003.homo.Aligned.out.sorted.bam
# 951     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B001545/P8_B001545_S212_L003.homo.Aligned.out.sorted.bam
# 952      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B002572/P8_B002572_S80_L004.homo.Aligned.out.sorted.bam
# 953      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B002573/P8_B002573_S20_L001.homo.Aligned.out.sorted.bam
# 954      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B001475/P9_B001475_S93_L003.homo.Aligned.out.sorted.bam
# 955     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B001543/P9_B001543_S129_L003.homo.Aligned.out.sorted.bam
# 956     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B001545/P9_B001545_S213_L003.homo.Aligned.out.sorted.bam
# 957      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B002573/P9_B002573_S21_L001.homo.Aligned.out.sorted.bam
#
#           sample_id  \
# 0     C3_1001000403
# 1     E3_1001000362
# 2     F1_1001000362
# 3     G5_1001000362
# 4     H1_1001000362
# 5     H7_1001000377
# 6    J11_1001000367
# 7     L2_1001000362
# 8    M10_1001000365
# 9     M2_1001000413
# 10    M3_1001000362
# 11    N2_1001000380
# 12   O23_1001000377
# 13   O24_1001000377
# 14       O7_B001797
# 0       A10_B000863
# 1       A11_B000861
# 2       A11_B003067
# 3       A14_B003067
# 4       A16_B003654
# 5       A17_B003654
# 6       A18_B003654
# 7       A19_B003654
# 8        A1_B000863
# 9        A1_B002568
# 10       A1_B003067
# 11       A1_B003646
# 12       A1_B003648
# 13      A21_B003654
# 14      A22_B003067
# ..              ...
# 928      P2_B002572
# 929      P3_B001464
# 930      P3_B001475
# 931      P3_B001543
# 932      P3_B002571
# 933      P4_B001464
# 934      P4_B002571
# 935      P5_B001464
# 936      P5_B001475
# 937      P5_B001543
# 938      P5_B001545
# 939      P5_B001556
# 940      P5_B002571
# 941      P5_B002572
# 942      P6_B001464
# 943      P6_B001543
# 944      P6_B001545
# 945      P6_B001556
# 946      P7_B001475
# 947      P7_B001543
# 948      P7_B002571
# 949      P7_B002572
# 950      P8_B001543
# 951      P8_B001545
# 952      P8_B002572
# 953      P8_B002573
# 954      P9_B001475
# 955      P9_B001543
# 956      P9_B001545
# 957      P9_B002573
#
#                                                                                                 output_vcf
# 0      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/C3_1001000403/C3_1001000403.vcf
# 1      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/E3_1001000362/E3_1001000362.vcf
# 2      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/F1_1001000362/F1_1001000362.vcf
# 3      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/G5_1001000362/G5_1001000362.vcf
# 4      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H1_1001000362/H1_1001000362.vcf
# 5      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/H7_1001000377/H7_1001000377.vcf
# 6    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/J11_1001000367/J11_1001000367.vcf
# 7      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/L2_1001000362/L2_1001000362.vcf
# 8    s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M10_1001000365/M10_1001000365.vcf
# 9      s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M2_1001000413/M2_1001000413.vcf
# 10     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/M3_1001000362/M3_1001000362.vcf
# 11     s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/N2_1001000380/N2_1001000380.vcf
# 12   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O23_1001000377/O23_1001000377.vcf
# 13   s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O24_1001000377/O24_1001000377.vcf
# 14           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180226/O7_B001797/O7_B001797.vcf
# 0          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A10_B000863/A10_B000863.vcf
# 1          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B000861/A11_B000861.vcf
# 2          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A11_B003067/A11_B003067.vcf
# 3          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A14_B003067/A14_B003067.vcf
# 4          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A16_B003654/A16_B003654.vcf
# 5          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A17_B003654/A17_B003654.vcf
# 6          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A18_B003654/A18_B003654.vcf
# 7          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A19_B003654/A19_B003654.vcf
# 8            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B000863/A1_B000863.vcf
# 9            s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B002568/A1_B002568.vcf
# 10           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003067/A1_B003067.vcf
# 11           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003646/A1_B003646.vcf
# 12           s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A1_B003648/A1_B003648.vcf
# 13         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A21_B003654/A21_B003654.vcf
# 14         s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180307/A22_B003067/A22_B003067.vcf
# ..                                                                                                     ...
# 928          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P2_B002572/P2_B002572.vcf
# 929          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B001464/P3_B001464.vcf
# 930          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B001475/P3_B001475.vcf
# 931          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B001543/P3_B001543.vcf
# 932          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P3_B002571/P3_B002571.vcf
# 933          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P4_B001464/P4_B001464.vcf
# 934          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P4_B002571/P4_B002571.vcf
# 935          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001464/P5_B001464.vcf
# 936          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001475/P5_B001475.vcf
# 937          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001543/P5_B001543.vcf
# 938          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001545/P5_B001545.vcf
# 939          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B001556/P5_B001556.vcf
# 940          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B002571/P5_B002571.vcf
# 941          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P5_B002572/P5_B002572.vcf
# 942          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001464/P6_B001464.vcf
# 943          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001543/P6_B001543.vcf
# 944          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001545/P6_B001545.vcf
# 945          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P6_B001556/P6_B001556.vcf
# 946          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B001475/P7_B001475.vcf
# 947          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B001543/P7_B001543.vcf
# 948          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B002571/P7_B002571.vcf
# 949          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P7_B002572/P7_B002572.vcf
# 950          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B001543/P8_B001543.vcf
# 951          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B001545/P8_B001545.vcf
# 952          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B002572/P8_B002572.vcf
# 953          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P8_B002573/P8_B002573.vcf
# 954          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B001475/P9_B001475.vcf
# 955          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B001543/P9_B001543.vcf
# 956          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B001545/P9_B001545.vcf
# 957          s3://darmanis-group/singlecell_lungadeno/nonImmune_bams_9.27/180911/P9_B002573/P9_B002573.vcf
#
# [6040 rows x 3 columns]

# %%
# add id col? 
big_df["id"] = big_df["sample_id"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-19465db67b9c> in <module>()
#       1 # add id col?
# ----> 2 big_df["id"] = big_df["sample_id"]
#
# NameError: name 'big_df' is not defined
